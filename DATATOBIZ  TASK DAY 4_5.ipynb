# %%
#Ignore warnings
import warnings
warnings.filterwarnings('ignore')
import os, sys
from keras.models import Model
from keras.layers import Input, LSTM, GRU, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 128
EPOCHS = 20
LSTM_NODES =256
NUM_SENTENCES = 20000
MAX_SENTENCE_LENGTH = 50
MAX_NUM_WORDS = 20000
EMBEDDING_SIZE = 100

# %%
input_sentences = []
output_sentences = []
output_sentences_inputs = []

count = 0
for line in open('fra.txt', encoding="utf-8"):
    count += 1
    if count > NUM_SENTENCES:
        break
    if '\t' not in line:
        continue
    input_sentence = line.rstrip().split('\t')[0]
    output = line.rstrip().split('\t')[1]

    output_sentence = output + ' <eos>'
    output_sentence_input = '<sos> ' + output

    input_sentences.append(input_sentence)
    output_sentences.append(output_sentence)
    output_sentences_inputs.append(output_sentence_input)

print("Number of sample input:", len(input_sentences))
print("Number of sample output:", len(output_sentences))
print("Number of sample output input:", len(output_sentences_inputs))
# Out:
# Number of sample input: 20000
# Number of sample output: 20000
# Number of sample output input: 20000

# %%
print("English sentence: ",input_sentences[180])
print("French translation: ",output_sentences[180])
# Out:
# English sentence:  Beat it.
# French translation:  Casse-toi de là. <eos>

# %%
#tokenize the input sentences(input language) 
input_tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
input_tokenizer.fit_on_texts(input_sentences)
input_integer_seq = input_tokenizer.texts_to_sequences(input_sentences)
print(input_integer_seq)
# Out:
# [[19], [19], [19], [531], [531], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [130], [67], [2398], [1432], [1432], [1432], [725], [59], [851], [851], [663], [663], [54], [54], [54], [104], [104], [104], [104], [104], [104], [104], [778], [778], [19, 44], [19, 44], [19, 44], [615], [615], [1, 62], [1, 62], [1, 75], [1, 187], [1, 187], [1, 187], [726, 28], [370], [370], [370], [370], [370], [370], [370], [370], [370], [370], [370], [370], [559], [559], [559], [224], [616], [616], [616], [229, 4], [229, 4], [229, 4], [229, 4], [1214], [1214], [1214], [1214], [106, 4], [106, 4], [31, 35], [31, 35], [31, 35], [19, 73], [19, 73], [19, 73], [60, 4], [60, 4], [60, 4], [60, 4], [60, 4], [60, 4], [1760, 40], [1760, 40], [480, 8], [480, 8], [1, 340], [1, 340], [1, 2399], [1, 1761], [1, 74], [1, 147], [1, 147], [1, 371], [1, 85], [1, 326], [1, 326], [1, 326], [1, 200], [1, 200], [7, 2400], [7, 142], [7, 142], [283], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [28, 213], [214], [214], [214], [214], [214], [284], [284], [284], [75, 4], [75, 4], [75, 4], [15, 75], [15, 187], [15, 187], [15, 187], [15, 187], [143, 3], [143, 41], [341], [341], [22, 251], [22, 251], [22, 251], [22, 188], [22, 327], [22, 327], [22, 327], [22, 327], [22, 327], [22, 327], [22, 327], [22, 327], [22, 327], [22, 463], [22, 111], [22, 111], [22, 111], [22, 111], [22, 111], [22, 111], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [304, 4], [934, 4], [934, 4], [934, 4], [934, 4], [1058, 4], [1058, 4], [1058, 4], [1058, 4], [133, 8], [133, 8], [133, 56], [133, 56], [45, 40], [45, 40], [45, 40], [45, 40], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [45, 44], [305, 4], [305, 4], [305, 4], [305, 4], [31, 3], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [31, 47], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 101], [19, 80], [19, 76], [19, 76], [19, 76], [19, 76], [19, 372], [19, 372], [935], [935], [935], [357, 44], [357, 44], [357, 44], [357, 44], [357, 44], [357, 44], [10, 147], [10, 200], [10, 200], [10, 936], [59, 8], [59, 8], [59, 8], [59, 8], [59, 8], [59, 56], [59, 56], [252, 4], [252, 4], [252, 4], [252, 4], [252, 44], [252, 44], [480, 3], [1, 342], [1, 439], [1, 1215], [1, 1215], [1, 265], [1, 937], [1, 306], [1, 1762], [1, 1762], [1, 532], [1, 1763], [1, 1216], [1, 852], [1, 852], [1, 1764], [1, 1764], [1, 343], [1, 343], [1, 343], [1, 1433], [34, 19], [7, 3], [7, 201], [7, 201], [7, 440], [7, 560], [7, 560], [7, 533], [7, 182], [7, 182], [7, 182], [7, 328], [7, 561], [7, 561], [14, 8], [534, 56], [534, 56], [64, 4], [64, 4], [1765, 4], [1765, 4], [481, 4], [481, 4], [481, 4], [481, 4], [504, 8], [504, 8], [285, 1059], [285, 1059], [329, 4], [329, 4], [329, 4], [329, 4], [8, 71], [242, 44], [242, 44], [150, 4], [150, 4], [150, 4], [150, 4], [150, 35], [150, 35], [2401, 35], [416], [664, 4], [664, 4], [395, 4], [395, 4], [395, 4], [395, 4], [395, 4], [62, 2], [62, 2], [62, 2], [62, 2], [62, 2], [62, 2], [243, 8], [243, 8], [313, 35], [313, 35], [313, 35], [313, 35], [313, 35], [286, 35], [286, 35], [1434, 4], [58, 617], [55, 4], [55, 4], [55, 4], [55, 4], [55, 4], [157, 8], [157, 8], [3, 187], [344, 35], [344, 35], [344, 35], [344, 35], [344, 35], [727, 35], [727, 35], [15, 74], [15, 85], [15, 85], [15, 85], [15, 85], [15, 85], [15, 85], [15, 85], [15, ...

# %%
word2idx_inputs = input_tokenizer.word_index
print('Total unique words in the input: %s' % len(word2idx_inputs))
# Out:
# Total unique words in the input: 3441

# %%
max_input_len = max(len(sen) for sen in input_integer_seq)
print("Length of longest sentence in input: %g" % max_input_len)
# Out:
# Length of longest sentence in input: 5

# %%
encoder_input_sequences = pad_sequences(input_integer_seq, maxlen=max_input_len)
print("encoder_input_sequences.shape:", encoder_input_sequences.shape)
print("encoder_input_sequences[180]:", encoder_input_sequences[180])
# Out:
# encoder_input_sequences.shape: (20000, 5)
# encoder_input_sequences[180]: [  0   0   0 304   4]

# %%
print(word2idx_inputs["join"])
print(word2idx_inputs["us"])
# Out:
# 534
# 56

# %%
#tokenize the output sentences(Output language)
output_tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, filters='')
output_tokenizer.fit_on_texts(output_sentences + output_sentences_inputs)
output_integer_seq = output_tokenizer.texts_to_sequences(output_sentences)
output_input_integer_seq = output_tokenizer.texts_to_sequences(output_sentences_inputs)
print(output_input_integer_seq)
# Out:
# [[2, 51, 4], [2, 703], [2, 428, 4], [2, 895, 4], [2, 4508], [2, 2670], [2, 2671], [2, 130, 238, 1024, 19, 238, 1949, 4], [2, 1505, 4], [2, 1950, 4], [2, 704, 4], [2, 2672, 4], [2, 2673, 4], [2, 2670], [2, 2671], [2, 130, 238, 1024, 19, 238, 1949, 4], [2, 1505, 4], [2, 1950, 4], [2, 704, 4], [2, 2672, 4], [2, 2673, 4], [2, 37, 6], [2, 27, 4509], [2, 19, 4510], [2, 4511], [2, 4512], [2, 65, 781, 4], [2, 19, 2674], [2, 4513], [2, 4514], [2, 1951], [2, 1951], [2, 27, 2675], [2, 4515], [2, 1200, 4], [2, 287, 4], [2, 341, 4], [2, 1025], [2, 287, 4], [2, 341, 4], [2, 4516], [2, 1025], [2, 1952], [2, 2676], [2, 4517], [2, 4518], [2, 4519], [2, 1026, 4], [2, 895, 4], [2, 3, 896], [2, 4520], [2, 2677], [2, 17, 429, 4], [2, 3, 68, 1027, 4], [2, 204, 384], [2, 2678, 556, 4], [2, 1201], [2, 1953], [2, 1954], [2, 2679, 2680], [2, 2681, 2682], [2, 46, 1506], [2, 1955, 4], [2, 1202, 4], [2, 2683], [2, 1203, 4], [2, 46, 187], [2, 217], [2, 4521], [2, 2684, 93, 18, 1204], [2, 4522], [2, 1507, 6], [2, 2685, 4], [2, 4523, 4], [2, 19, 4524, 4], [2, 4525, 4], [2, 4526, 4], [2, 4527, 4], [2, 4528, 4], [2, 1508, 4], [2, 19, 69, 1508, 4], [2, 312, 4], [2, 4529, 4], [2, 4530], [2, 4531], [2, 1956], [2, 2686, 4], [2, 313], [2, 1957, 129], [2, 1958, 129], [2, 1509, 129], [2, 17, 4532, 4], [2, 1205, 4], [2, 4533, 4], [2, 4534], [2, 4535], [2, 1510, 4536], [2, 4537], [2, 4538], [2, 1206, 101, 205, 782, 4], [2, 1511, 101, 238, 782, 4], [2, 3, 7, 2687], [2, 3, 7, 1959], [2, 17, 4539], [2, 3, 2688], [2, 3, 1028], [2, 3, 7, 402], [2, 3, 7, 783], [2, 17, 462], [2, 17, 233], [2, 3, 4540], [2, 3, 4541], [2, 204, 784], [2, 1960], [2, 17, 897], [2, 17, 4542, 516], [2, 3, 95, 70], [2, 27, 785], [2, 1029, 4], [2, 16, 11, 1961], [2, 4543], [2, 1030, 15, 4544], [2, 24, 403, 4545], [2, 212, 4546], [2, 16, 1030, 15, 1962, 4], [2, 9, 174, 8, 11, 1962, 4], [2, 16, 4547, 4], [2, 24, 327, 1512, 4], [2, 1030, 15, 1962, 4], [2, 1207], [2, 372, 6], [2, 705, 126, 6], [2, 705, 149, 6], [2, 149, 6], [2, 312, 4], [2, 312, 4], [2, 1031], [2, 898], [2, 4548], [2, 1208], [2, 71, 1208], [2, 10, 79, 384], [2, 10, 4549], [2, 10, 517, 1209], [2, 10, 4550], [2, 300, 19, 35], [2, 4551], [2, 1963], [2, 1513, 4], [2, 64, 899, 4], [2, 54, 899, 4], [2, 54, 2689, 4], [2, 64, 1964, 4], [2, 64, 132, 4], [2, 54, 132, 4], [2, 54, 4552, 4], [2, 64, 2690, 4], [2, 54, 2690, 4], [2, 54, 4553, 4], [2, 64, 786], [2, 64, 706], [2, 54, 1965], [2, 64, 385], [2, 64, 518, 4], [2, 64, 787, 4], [2, 54, 518, 4], [2, 54, 787, 4], [2, 54, 1966, 4], [2, 54, 1967, 4], [2, 51, 45, 92, 1968, 4], [2, 900], [2, 1514], [2, 373, 4], [2, 4554, 13, 788, 4], [2, 1969, 13, 788, 4], [2, 373, 901], [2, 51, 253, 4], [2, 1210, 4], [2, 902, 13, 789], [2, 2691, 15, 127], [2, 4555, 15, 127], [2, 1970, 4], [2, 1971], [2, 902, 13, 788, 901], [2, 790], [2, 428, 4], [2, 707, 4], [2, 4556], [2, 4557], [2, 4558], [2, 4559], [2, 4560], [2, 4561], [2, 4562], [2, 4563], [2, 1515, 4], [2, 4564], [2, 4565, 4], [2, 4566, 4], [2, 2692], [2, 1211], [2, 1212, 4], [2, 2693, 4], [2, 1972], [2, 24, 2694], [2, 16, 11, 4567, 328, 4], [2, 1973], [2, 1974], [2, 4568, 4], [2, 4569, 4], [2, 161, 4], [2, 1973], [2, 1974], [2, 191, 489, 4], [2, 276, 489, 4], [2, 903, 489, 4], [2, 1032, 489, 4], [2, 51, 264, 35], [2, 1516], [2, 2695], [2, 900], [2, 2696], [2, 1514], [2, 2697, 4], [2, 557, 4], [2, 904, 4], [2, 1975, 4], [2, 1210, 4], [2, 46, 4570, 4], [2, 902, 13, 789], [2, 1970, 4], [2, 609, 4571, 4], [2, 1976, 13, 788, 4], [2, 1977], [2, 905, 4], [2, 707, 4], [2, 1516], [2, 2695], [2, 900], [2, 2696], [2, 1514], [2, 2697, 4], [2, 557, 4], [2, 904, 4], [2, 1210, 4], [2, 902, 13, 789], [2, 1970, 4], [2, 1977], [2, 428, 4], [2, 905, 4], [2, 707, 4], [2, 900], [2, 373, 4], [2, 708, 24, 4], [2, 790], [2, 906], [2, 428, 4], [2, 905, 4], [2, 707, 4], [2, 51, 45, 92, 1968, 4], [2, 373, 4], [2, 1975, 4], [2, 1969, 13, 788, 4], [2, 373, 901], [2, 51, 253, 4], [2, 1210, 4], [2, 790], [2, 906], [2, 428, 4], [2, 905, 4], [2, 707, 4], [2, 2698], [2, 2699, 19, 18, 128], [2, ...

# %%
word2idx_outputs = output_tokenizer.word_index
print('Total unique words in the output: %s' % len(word2idx_outputs))
# Out:
# Total unique words in the output: 9499

# %%
num_words_output = len(word2idx_outputs) + 1
max_out_len = max(len(sen) for sen in output_integer_seq)
print("Length of longest sentence in the output: %g" % max_out_len)
# Out:
# Length of longest sentence in the output: 12

# %%
decoder_input_sequences = pad_sequences(output_input_integer_seq, maxlen=max_out_len, padding='post')
print("decoder_input_sequences.shape:", decoder_input_sequences.shape)
print("decoder_input_sequences[180]:", decoder_input_sequences[180])
# Out:
# decoder_input_sequences.shape: (20000, 12)
# decoder_input_sequences[180]: [   2 4555   15  127    0    0    0    0    0    0    0    0]

# %%
print(word2idx_outputs["<sos>"])
print(word2idx_outputs["joignez-vous"])
print(word2idx_outputs["à"])
print(word2idx_outputs["nous."])
# Out:
# 2
# 2711
# 19
# 219

# %%
decoder_output_sequences = pad_sequences(output_integer_seq, maxlen=max_out_len, padding='post')
print("decoder_output_sequences.shape:", decoder_output_sequences.shape)
# Out:
# decoder_output_sequences.shape: (20000, 12)

# %%
from numpy import array
from numpy import asarray
from numpy import zeros

embeddings_dictionary = dict()

glove_file = open('C:/Users/karthick/Downloads/glove.6B.100d.txt/glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary[word] = vector_dimensions
glove_file.close()

# %%
num_words = min(MAX_NUM_WORDS, len(word2idx_inputs) + 1)
embedding_matrix = zeros((num_words, EMBEDDING_SIZE))
for word, index in word2idx_inputs.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
print(embeddings_dictionary["ill"])
# Out:
# [ 0.12648    0.1366     0.22192   -0.025204  -0.7197     0.66147
#   0.48509    0.057223   0.13829   -0.26375   -0.23647    0.74349
#   0.46737   -0.462      0.20031   -0.26302    0.093948  -0.61756
#  -0.28213    0.1353     0.28213    0.21813    0.16418    0.22547
#  -0.98945    0.29624   -0.62476   -0.29535    0.21534    0.92274
#   0.38388    0.55744   -0.14628   -0.15674   -0.51941    0.25629
#  -0.0079678  0.12998   -0.029192   0.20868   -0.55127    0.075353
#   0.44746   -0.71046    0.75562    0.010378   0.095229   0.16673
#   0.22073   -0.46562   -0.10199   -0.80386    0.45162    0.45183
#   0.19869   -1.6571     0.7584    -0.40298    0.82426   -0.386
#   0.0039546  0.61318    0.02701   -0.3308    -0.095652  -0.082164
#   0.7858     0.13394   -0.32715   -0.31371   -0.20247   -0.73001
#  -0.49343    0.56445    0.61038    0.36777   -0.070182   0.44859
#  -0.61774   -0.18849    0.65592    0.44797   -0.10469    0.62512
#  -1.9474    -0.60622    0.073874   0.50013   -1.1278    -0.42066
#  -0.37322   -0.50538    0.59171    0.46534   -0.42482    0.83265
#   0.081548  -0.44147   -0.084311  -1.2304   ]

# %%
print(embedding_matrix[539])
# Out:
# [-1.23510003e-01  5.82360029e-01  9.39920008e-01 -5.65240011e-02
#   1.67850003e-01 -2.40789995e-01  3.60240005e-02 -1.39980003e-01
#  -1.35020003e-01  4.10090014e-02  1.94969997e-01  3.83430004e-01
#   1.10760003e-01 -4.15609986e-01  1.50639996e-01 -5.81780016e-01
#  -3.76370013e-01 -9.37810019e-02 -3.81440014e-01  4.19869989e-01
#   1.01559997e+00  7.40190029e-01  2.21249998e-01 -1.41049996e-01
#  -4.16350007e-01 -9.45720002e-02 -1.30559996e-01 -5.32060027e-01
#  -1.02069996e-01 -3.11580002e-01  3.11659992e-01 -3.99710014e-02
#   1.58960000e-01 -5.45970015e-02  5.97019970e-01  4.45329994e-01
#   4.51750010e-02 -1.13820001e-01 -7.92980015e-01  2.15570003e-01
#  -4.88249987e-01 -3.22939992e-01 -4.70840000e-02 -1.71920002e-01
#  -9.04999971e-02 -3.88779998e-01  1.04020000e+00  1.26980003e-02
#   1.27130002e-01 -3.56429994e-01  6.26600027e-01 -1.56069994e-01
#   1.12539999e-01  1.04149997e+00 -3.17950010e-01 -2.34139991e+00
#  -1.59590006e-01 -2.40899995e-01  1.75010002e+00  2.64629990e-01
#  -9.47749987e-02  1.17460001e+00 -3.47559988e-01  1.79429993e-01
#   5.98420024e-01  1.33149996e-01  9.80189964e-02  9.73400027e-02
#   2.61370003e-01  2.40570009e-02  2.55870014e-01 -4.63220000e-01
#  -1.63010001e-01 -1.65519997e-01  4.11309987e-01 -4.51999992e-01
#  -1.85090005e-01 -1.50900006e-01 -9.20140028e-01 -6.70910013e-05
#   5.43860018e-01  4.18080002e-01 -5.70219994e-01 -3.36670011e-01
#  -1.60650003e+00 -3.63189995e-01  2.91839987e-01  5.63080013e-02
#  -2.75709987e-01 -1.88429996e-01  2.13569999e-01 -8.14749971e-02
#  -3.89519989e-01 -5.47810011e-02 -5.91660023e-01  3.14370006e-01
#  -5.65649986e-01  1.98420003e-01  5.17620027e-01  1.20930001e-01]

# %%
embedding_layer = Embedding(num_words, EMBEDDING_SIZE, weights=[embedding_matrix], input_length=max_input_len)

# %%
decoder_targets_one_hot = np.zeros((
        len(input_sentences),
        max_out_len,
        num_words_output
    ),
    dtype='float32'
)

# %%
decoder_targets_one_hot.shape
# Out:
# (20000, 12, 9500)

# %%
for i, d in enumerate(decoder_output_sequences):
    for t, word in enumerate(d):
        decoder_targets_one_hot[i, t, word] = 1

# %%
encoder_inputs_placeholder = Input(shape=(max_input_len,))
x = embedding_layer(encoder_inputs_placeholder)
encoder = LSTM(LSTM_NODES, return_state=True)

encoder_outputs, h, c = encoder(x)
encoder_states = [h, c]

# %%
decoder_inputs_placeholder = Input(shape=(max_out_len,))

decoder_embedding = Embedding(num_words_output, LSTM_NODES)
decoder_inputs_x = decoder_embedding(decoder_inputs_placeholder)

decoder_lstm = LSTM(LSTM_NODES, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs_x, initial_state=encoder_states)

# %%
decoder_dense = Dense(num_words_output, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs_placeholder,
  decoder_inputs_placeholder], decoder_outputs)
model.compile(
    optimizer='rmsprop',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
r = model.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
)
# Out:
# Epoch 1/20
# 282/282 [==============================] - 103s 302ms/step - loss: 2.7097 - accuracy: 0.6705 - val_loss: 2.0943 - val_accuracy: 0.7047
# Epoch 2/20
# 282/282 [==============================] - 86s 304ms/step - loss: 1.5637 - accuracy: 0.7666 - val_loss: 1.8577 - val_accuracy: 0.7332
# Epoch 3/20
# 282/282 [==============================] - 82s 290ms/step - loss: 1.3316 - accuracy: 0.8026 - val_loss: 1.7410 - val_accuracy: 0.7492
# Epoch 4/20
# 282/282 [==============================] - 82s 290ms/step - loss: 1.2125 - accuracy: 0.8161 - val_loss: 1.6376 - val_accuracy: 0.7644
# Epoch 5/20
# 282/282 [==============================] - 82s 292ms/step - loss: 1.1234 - accuracy: 0.8262 - val_loss: 1.5933 - val_accuracy: 0.7690
# Epoch 6/20
# 282/282 [==============================] - 82s 290ms/step - loss: 1.0379 - accuracy: 0.8376 - val_loss: 1.5639 - val_accuracy: 0.7741
# Epoch 7/20
# 282/282 [==============================] - 83s 295ms/step - loss: 0.9734 - accuracy: 0.8454 - val_loss: 1.5497 - val_accuracy: 0.7745
# Epoch 8/20
# 282/282 [==============================] - 83s 294ms/step - loss: 0.9240 - accuracy: 0.8516 - val_loss: 1.5561 - val_accuracy: 0.7740
# Epoch 9/20
# 282/282 [==============================] - 81s 289ms/step - loss: 0.8870 - accuracy: 0.8577 - val_loss: 1.5549 - val_accuracy: 0.7723
# Epoch 10/20
# 282/282 [==============================] - 84s 298ms/step - loss: 0.8444 - accuracy: 0.8635 - val_loss: 1.5359 - val_accuracy: 0.7778
# Epoch 11/20
# 282/282 [==============================] - 79s 280ms/step - loss: 0.8063 - accuracy: 0.8694 - val_loss: 1.5372 - val_accuracy: 0.7776
# Epoch 12/20
# 282/282 [==============================] - 91s 322ms/step - loss: 0.7732 - accuracy: 0.8753 - val_loss: 1.5505 - val_accuracy: 0.7784
# Epoch 13/20
# 282/282 [==============================] - 88s 313ms/step - loss: 0.7519 - accuracy: 0.8795 - val_loss: 1.5477 - val_accuracy: 0.7773
# Epoch 14/20
# 282/282 [==============================] - 83s 296ms/step - loss: 0.7163 - accuracy: 0.8843 - val_loss: 1.5368 - val_accuracy: 0.7818
# Epoch 15/20
# 282/282 [==============================] - 88s 311ms/step - loss: 0.6910 - accuracy: 0.8886 - val_loss: 1.5618 - val_accuracy: 0.7798
# Epoch 16/20
# 282/282 [==============================] - 91s 322ms/step - loss: 0.6747 - accuracy: 0.8912 - val_loss: 1.5584 - val_accuracy: 0.7806
# Epoch 17/20
# 282/282 [==============================] - 83s 294ms/step - loss: 0.6618 - accuracy: 0.8943 - val_loss: 1.5917 - val_accuracy: 0.7817
# Epoch 18/20
# 282/282 [==============================] - 88s 311ms/step - loss: 0.6398 - accuracy: 0.8974 - val_loss: 1.5880 - val_accuracy: 0.7819
# Epoch 19/20
# 282/282 [==============================] - 94s 332ms/step - loss: 0.6278 - accuracy: 0.9002 - val_loss: 1.5976 - val_accuracy: 0.7815
# Epoch 20/20
# 282/282 [==============================] - 90s 318ms/step - loss: 0.6137 - accuracy: 0.9029 - val_loss: 1.5878 - val_accuracy: 0.7840

# %%
encoder_model = Model(encoder_inputs_placeholder, encoder_states)

# %%
decoder_state_input_h = Input(shape=(LSTM_NODES,))
decoder_state_input_c = Input(shape=(LSTM_NODES,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# %%
decoder_inputs_single = Input(shape=(1,))
decoder_inputs_single_x = decoder_embedding(decoder_inputs_single)

# %%
decoder_outputs, h, c = decoder_lstm(decoder_inputs_single_x, initial_state=decoder_states_inputs)

# %%
decoder_states = [h, c]
decoder_outputs = decoder_dense(decoder_outputs)

# %%
decoder_model = Model(
    [decoder_inputs_single] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# %%
idx2word_input = {v:k for k, v in word2idx_inputs.items()}
idx2word_target = {v:k for k, v in word2idx_outputs.items()}

# %%
def translate_sentence(input_seq):
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = word2idx_outputs['<sos>']
    eos = word2idx_outputs['<eos>']
    output_sentence = []

    for _ in range(max_out_len):
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        idx = np.argmax(output_tokens[0, 0, :])

        if eos == idx:
            break

        word = ''

        if idx > 0:
            word = idx2word_target[idx]
            output_sentence.append(word)

        target_seq[0, 0] = idx
        states_value = [h, c]

    return ' '.join(output_sentence)

# %%
i = np.random.choice(len(input_sentences))
input_seq = encoder_input_sequences[i:i+1]
translation = translate_sentence(input_seq)
print('-')
print('Input:', input_sentences[i])
print('Response:', translation)
# Out:
# -
# Input: I'm so tired.
# Response: je suis tellement fatigué.

# %%
i = np.random.choice(len(input_sentences))
input_seq = encoder_input_sequences[i:i+1]
translation = translate_sentence(input_seq)
print('-')
print('Input:', input_sentences[i])
print('Response:', translation)
# Out:
# -
# Input: It's an outrage.
# Response: c'est un accord.

# %%
from tensorflow.keras.optimizers import Adam

# %%
model2 = Model([encoder_inputs_placeholder,decoder_inputs_placeholder], decoder_outputs)
model2.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
r = model2.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
)
# Out:
# Epoch 1/20
# 282/282 [==============================] - 104s 312ms/step - loss: 3.5015 - accuracy: 0.6447 - val_loss: 2.2510 - val_accuracy: 0.6972
# Epoch 2/20
# 282/282 [==============================] - 85s 303ms/step - loss: 1.7701 - accuracy: 0.7330 - val_loss: 2.0738 - val_accuracy: 0.7117
# Epoch 3/20
# 282/282 [==============================] - 92s 327ms/step - loss: 1.5431 - accuracy: 0.7666 - val_loss: 1.9396 - val_accuracy: 0.7244
# Epoch 4/20
# 282/282 [==============================] - 94s 334ms/step - loss: 1.3614 - accuracy: 0.7908 - val_loss: 1.8403 - val_accuracy: 0.7367
# Epoch 5/20
# 282/282 [==============================] - 95s 336ms/step - loss: 1.2197 - accuracy: 0.8056 - val_loss: 1.7696 - val_accuracy: 0.7479
# Epoch 6/20
# 282/282 [==============================] - 100s 354ms/step - loss: 1.0971 - accuracy: 0.8171 - val_loss: 1.7158 - val_accuracy: 0.7558
# Epoch 7/20
# 282/282 [==============================] - 105s 374ms/step - loss: 0.9944 - accuracy: 0.8270 - val_loss: 1.6872 - val_accuracy: 0.7607
# Epoch 8/20
# 282/282 [==============================] - 100s 354ms/step - loss: 0.9092 - accuracy: 0.8340 - val_loss: 1.6554 - val_accuracy: 0.7640
# Epoch 9/20
# 282/282 [==============================] - 94s 335ms/step - loss: 0.8296 - accuracy: 0.8412 - val_loss: 1.6332 - val_accuracy: 0.7667
# Epoch 10/20
# 282/282 [==============================] - 92s 326ms/step - loss: 0.7517 - accuracy: 0.8509 - val_loss: 1.6244 - val_accuracy: 0.7707
# Epoch 11/20
# 282/282 [==============================] - 87s 308ms/step - loss: 0.6828 - accuracy: 0.8585 - val_loss: 1.6150 - val_accuracy: 0.7715
# Epoch 12/20
# 282/282 [==============================] - 88s 311ms/step - loss: 0.6237 - accuracy: 0.8667 - val_loss: 1.6098 - val_accuracy: 0.7744
# Epoch 13/20
# 282/282 [==============================] - 91s 322ms/step - loss: 0.5671 - accuracy: 0.8744 - val_loss: 1.6117 - val_accuracy: 0.7744
# Epoch 14/20
# 282/282 [==============================] - 84s 297ms/step - loss: 0.5176 - accuracy: 0.8818 - val_loss: 1.6073 - val_accuracy: 0.7745
# Epoch 15/20
# 282/282 [==============================] - 86s 305ms/step - loss: 0.4756 - accuracy: 0.8888 - val_loss: 1.6207 - val_accuracy: 0.7742
# Epoch 16/20
# 282/282 [==============================] - 90s 319ms/step - loss: 0.4365 - accuracy: 0.8963 - val_loss: 1.6244 - val_accuracy: 0.7747
# Epoch 17/20
# 282/282 [==============================] - 87s 310ms/step - loss: 0.3969 - accuracy: 0.9034 - val_loss: 1.6107 - val_accuracy: 0.7778
# Epoch 18/20
# 282/282 [==============================] - 88s 310ms/step - loss: 0.3658 - accuracy: 0.9086 - val_loss: 1.6237 - val_accuracy: 0.7788
# Epoch 19/20
# 282/282 [==============================] - 84s 300ms/step - loss: 0.3322 - accuracy: 0.9152 - val_loss: 1.6366 - val_accuracy: 0.7786
# Epoch 20/20
# 282/282 [==============================] - 91s 322ms/step - loss: 0.3085 - accuracy: 0.9201 - val_loss: 1.6413 - val_accuracy: 0.7778

# %%
from tensorflow.keras.layers import Bidirectional

# %%
encoder_inputs_placeholder = Input(shape=(max_input_len,))
x = embedding_layer(encoder_inputs_placeholder)
encoder = LSTM(LSTM_NODES, return_state=True)

encoder_outputs, h, c = encoder(x)
encoder_states = [h, c]

# %%
decoder_inputs_placeholder = Input(shape=(max_out_len,))

decoder_embedding = Embedding(num_words_output, LSTM_NODES)
decoder_inputs_x = decoder_embedding(decoder_inputs_placeholder)

decoder_lstm = LSTM(LSTM_NODES, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs_x, initial_state=encoder_states)

# %%
from tensorflow.keras.layers import Dropout
dropout = Dropout(rate=0.3)
decoder_outputs = dropout(decoder_outputs)

# %%
decoder_dense = Dense(num_words_output, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model2 = Model([encoder_inputs_placeholder,decoder_inputs_placeholder], decoder_outputs)
model2.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
r = model2.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=50,
    validation_split=0.3,
)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 83s 366ms/step - loss: 3.7030 - accuracy: 0.6382 - val_loss: 2.2420 - val_accuracy: 0.6903
# Epoch 2/50
# 219/219 [==============================] - 80s 364ms/step - loss: 1.7661 - accuracy: 0.7381 - val_loss: 2.0421 - val_accuracy: 0.7137
# Epoch 3/50
# 219/219 [==============================] - 77s 350ms/step - loss: 1.5232 - accuracy: 0.7682 - val_loss: 1.8864 - val_accuracy: 0.7404
# Epoch 4/50
# 219/219 [==============================] - 76s 347ms/step - loss: 1.3385 - accuracy: 0.7983 - val_loss: 1.7818 - val_accuracy: 0.7568
# Epoch 5/50
# 219/219 [==============================] - 78s 356ms/step - loss: 1.1855 - accuracy: 0.8156 - val_loss: 1.7036 - val_accuracy: 0.7652
# Epoch 6/50
# 219/219 [==============================] - 80s 368ms/step - loss: 1.0670 - accuracy: 0.8263 - val_loss: 1.6486 - val_accuracy: 0.7711
# Epoch 7/50
# 219/219 [==============================] - 78s 358ms/step - loss: 0.9584 - accuracy: 0.8352 - val_loss: 1.6119 - val_accuracy: 0.7767
# Epoch 8/50
# 219/219 [==============================] - 80s 363ms/step - loss: 0.8676 - accuracy: 0.8433 - val_loss: 1.5867 - val_accuracy: 0.7803
# Epoch 9/50
# 219/219 [==============================] - 81s 371ms/step - loss: 0.7847 - accuracy: 0.8519 - val_loss: 1.5708 - val_accuracy: 0.7835
# Epoch 10/50
# 219/219 [==============================] - 80s 366ms/step - loss: 0.6990 - accuracy: 0.8607 - val_loss: 1.5627 - val_accuracy: 0.7839
# Epoch 11/50
# 219/219 [==============================] - 74s 339ms/step - loss: 0.6395 - accuracy: 0.8683 - val_loss: 1.5554 - val_accuracy: 0.7860
# Epoch 12/50
# 219/219 [==============================] - 75s 342ms/step - loss: 0.5755 - accuracy: 0.8763 - val_loss: 1.5583 - val_accuracy: 0.7872
# Epoch 13/50
# 219/219 [==============================] - 75s 341ms/step - loss: 0.5213 - accuracy: 0.8854 - val_loss: 1.5500 - val_accuracy: 0.7893
# Epoch 14/50
# 219/219 [==============================] - 78s 356ms/step - loss: 0.4688 - accuracy: 0.8933 - val_loss: 1.5640 - val_accuracy: 0.7902
# Epoch 15/50
# 219/219 [==============================] - 76s 346ms/step - loss: 0.4220 - accuracy: 0.9017 - val_loss: 1.5644 - val_accuracy: 0.7904
# Epoch 16/50
# 219/219 [==============================] - 75s 341ms/step - loss: 0.3866 - accuracy: 0.9073 - val_loss: 1.5674 - val_accuracy: 0.7905
# Epoch 17/50
# 219/219 [==============================] - 82s 374ms/step - loss: 0.3484 - accuracy: 0.9147 - val_loss: 1.5714 - val_accuracy: 0.7914
# Epoch 18/50
# 219/219 [==============================] - 80s 364ms/step - loss: 0.3209 - accuracy: 0.9207 - val_loss: 1.5768 - val_accuracy: 0.7916
# Epoch 19/50
# 219/219 [==============================] - 89s 406ms/step - loss: 0.2898 - accuracy: 0.9264 - val_loss: 1.5883 - val_accuracy: 0.7931
# Epoch 20/50
# 219/219 [==============================] - 82s 373ms/step - loss: 0.2658 - accuracy: 0.9310 - val_loss: 1.5953 - val_accuracy: 0.7919
# Epoch 21/50
# 219/219 [==============================] - 82s 376ms/step - loss: 0.2470 - accuracy: 0.9334 - val_loss: 1.5970 - val_accuracy: 0.7916
# Epoch 22/50
# 219/219 [==============================] - 75s 345ms/step - loss: 0.2309 - accuracy: 0.9364 - val_loss: 1.6067 - val_accuracy: 0.7928
# Epoch 23/50
# 219/219 [==============================] - 75s 342ms/step - loss: 0.2129 - accuracy: 0.9393 - val_loss: 1.6180 - val_accuracy: 0.7921
# Epoch 24/50
# 219/219 [==============================] - 76s 349ms/step - loss: 0.1973 - accuracy: 0.9414 - val_loss: 1.6288 - val_accuracy: 0.7910
# Epoch 25/50
# 219/219 [==============================] - 79s 360ms/step - loss: 0.1845 - accuracy: 0.9443 - val_loss: 1.6332 - val_accuracy: 0.7917
# Epoch 26/50
# 219/219 [==============================] - 77s 351ms/step - loss: 0.1755 - accuracy: 0.9447 - val_loss: 1.6453 - val_accuracy: 0.7913
# Epoch 27/50
# 219/219 [==============================] - 75s 345ms/step - loss: 0.1644 - accuracy: 0.9469 - val_loss: 1.6467 - val_accuracy: 0.7921
# Epoch 28/50
# 219/219 [==============================] - 80s 366ms/step - loss: 0.1564 - accuracy: 0.9482 - val_loss: 1.6639 - val_accuracy: 0.7923
# Epoch 29/50
# 219/219 [==============================] - 82s 373ms/step - loss: 0.1504 - accuracy: 0.9482 - val_loss: 1.6668 - val_accuracy: 0.7913
# Epoch 30/50
# 219/219 [==============================] - 86s 392ms/step - loss: 0.1428 - accuracy: 0.9494 - val_loss: 1.6898 - val_accuracy: 0.7913
# Epoch 31/50
# 219/219 [==============================] - 91s 414ms/step - loss: 0.1394 - accuracy: 0.9493 - val_loss: 1.6979 - val_accuracy: 0.7919
# Epoch 32/50
# 219/219 [==============================] - 87s 399ms/step - loss: 0.1337 - accuracy: 0.9509 - val_loss: 1.6931 - val_accuracy: 0.7917
# Epoch 33/50
# 219/219 [==============================] - 81s 371ms/step - loss: 0.1281 - accuracy: 0.9513 - val_loss: 1.7042 - val_accuracy: 0.7914
# Epoch 34/50
# 219/219 [==============================] - 76s 347ms/step - loss: 0.1259 - accuracy: 0.9509 - val_loss: 1.7208 - val_accuracy: 0.7910
# Epoch 35/50
# 219/219 [==============================] - 76s 349ms/step - loss: 0.1219 - accuracy: 0.9520 - val_loss: 1.7302 - val_accuracy: 0.7914
# Epoch 36/50
# 219/219 [==============================] - 75s 343ms/step - loss: 0.1184 - accuracy: 0.9523 - val_loss: 1.7320 - val_accuracy: 0.7920
# Epoch 37/50
# 219/219 [==============================] - 75s 343ms/step - loss: 0.1156 - accuracy: 0.9524 - val_loss: 1.7428 - val_accuracy: 0.7914
# Epoch 38/50
# 219/219 [==============================] - 74s 338ms/step - loss: 0.1131 - accuracy: 0.9527 - val_loss: 1.7521 - val_accuracy: 0.7912
# Epoch 39/50
# 219/219 [==============================] - 75s 341ms/step - loss: 0.1105 - accuracy: 0.9529 - val_loss: 1.7596 - val_accuracy: 0.7907
# Epoch 40/50
# 219/219 [==============================] - 74s 337ms/step - loss: 0.1093 - accuracy: 0.9523 - val_loss: 1.7622 - val_accuracy: 0.7923
# Epoch 41/50
# 219/219 [==============================] - 78s 357ms/step - loss: 0.1068 - accuracy: 0.9535 - val_loss: 1.7727 - val_accuracy: 0.7916
# Epoch 42/50
# 219/219 [==============================] - 75s 342ms/step - loss: 0.1046 - accuracy: 0.9534 - val_loss: 1.7998 - val_accuracy: 0.7915
# Epoch 43/50
# 219/219 [==============================] - 75s 345ms/step - loss: 0.1048 - accuracy: 0.9531 - val_loss: 1.7969 - val_accuracy: 0.7912
# Epoch 44/50
# 219/219 [==============================] - 78s 358ms/step - loss: 0.1029 - accuracy: 0.9531 - val_loss: 1.7971 - val_accuracy: 0.7902
# Epoch 45/50
# 219/219 [==============================] - 75s 343ms/step - loss: 0.0996 - accuracy: 0.9540 - val_loss: 1.8010 - val_accuracy: 0.7904
# Epoch 46/50
# 219/219 [==============================] - 79s 363ms/step - loss: 0.1012 - accuracy: 0.9539 - val_loss: 1.8027 - val_accuracy: 0.7910
# Epoch 47/50
# 219/219 [==============================] - 82s 377ms/step - loss: 0.0983 - accuracy: 0.9540 - val_loss: 1.8173 - val_accuracy: 0.7898
# Epoch 48/50
# 219/219 [==============================] - 85s 389ms/step - loss: 0.0977 - accuracy: 0.9537 - val_loss: 1.8248 - val_accuracy: 0.7908
# Epoch 49/50
# 219/219 [==============================] - 77s 354ms/step - loss: 0.0969 - accuracy: 0.9537 - val_loss: 1.8399 - val_accuracy: 0.7899
# Epoch 50/50
# 219/219 [==============================] - 73s 335ms/step - loss: 0.0958 - accuracy: 0.9542 - val_loss: 1.8451 - val_accuracy: 0.7906

# %%
model3 = Model([encoder_inputs_placeholder,decoder_inputs_placeholder], decoder_outputs)
model3.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
r = model2.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=10,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 125/125 [==============================] - 70s 546ms/step - loss: 0.1742 - accuracy: 0.9439 - val_loss: 1.5144 - val_accuracy: 0.8110
# Epoch 2/10
# 125/125 [==============================] - 64s 516ms/step - loss: 0.1438 - accuracy: 0.9464 - val_loss: 1.4763 - val_accuracy: 0.8144
# Epoch 3/10
# 125/125 [==============================] - 65s 520ms/step - loss: 0.1271 - accuracy: 0.9478 - val_loss: 1.4483 - val_accuracy: 0.8174
# Epoch 4/10
# 125/125 [==============================] - 66s 531ms/step - loss: 0.1162 - accuracy: 0.9486 - val_loss: 1.4314 - val_accuracy: 0.8203
# Epoch 5/10
# 125/125 [==============================] - 66s 530ms/step - loss: 0.1084 - accuracy: 0.9494 - val_loss: 1.4312 - val_accuracy: 0.8223
# Epoch 6/10
# 125/125 [==============================] - 75s 605ms/step - loss: 0.1029 - accuracy: 0.9502 - val_loss: 1.4330 - val_accuracy: 0.8252
# Epoch 7/10
# 125/125 [==============================] - 71s 570ms/step - loss: 0.0989 - accuracy: 0.9509 - val_loss: 1.4310 - val_accuracy: 0.8267
# Epoch 8/10
# 125/125 [==============================] - 71s 567ms/step - loss: 0.0965 - accuracy: 0.9512 - val_loss: 1.4353 - val_accuracy: 0.8276
# Epoch 9/10
# 125/125 [==============================] - 68s 549ms/step - loss: 0.0947 - accuracy: 0.9514 - val_loss: 1.4283 - val_accuracy: 0.8276
# Epoch 10/10
# 125/125 [==============================] - 65s 522ms/step - loss: 0.0936 - accuracy: 0.9514 - val_loss: 1.4328 - val_accuracy: 0.8279

# %%
r = model3.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=20,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 81s 527ms/step - loss: 4.5015 - accuracy: 0.6072 - val_loss: 2.5003 - val_accuracy: 0.6602
# Epoch 2/20
# 125/125 [==============================] - 64s 511ms/step - loss: 1.9707 - accuracy: 0.7240 - val_loss: 2.2599 - val_accuracy: 0.6891
# Epoch 3/20
# 125/125 [==============================] - 63s 507ms/step - loss: 1.7609 - accuracy: 0.7371 - val_loss: 2.1582 - val_accuracy: 0.6950
# Epoch 4/20
# 125/125 [==============================] - 63s 501ms/step - loss: 1.6502 - accuracy: 0.7471 - val_loss: 2.0921 - val_accuracy: 0.7050
# Epoch 5/20
# 125/125 [==============================] - 64s 514ms/step - loss: 1.5498 - accuracy: 0.7564 - val_loss: 2.0202 - val_accuracy: 0.7131
# Epoch 6/20
# 125/125 [==============================] - 65s 519ms/step - loss: 1.4480 - accuracy: 0.7745 - val_loss: 1.9561 - val_accuracy: 0.7240
# Epoch 7/20
# 125/125 [==============================] - 66s 527ms/step - loss: 1.3524 - accuracy: 0.7871 - val_loss: 1.9039 - val_accuracy: 0.7307
# Epoch 8/20
# 125/125 [==============================] - 65s 518ms/step - loss: 1.2618 - accuracy: 0.7973 - val_loss: 1.8567 - val_accuracy: 0.7383
# Epoch 9/20
# 125/125 [==============================] - 83s 664ms/step - loss: 1.1815 - accuracy: 0.8064 - val_loss: 1.8106 - val_accuracy: 0.7471
# Epoch 10/20
# 125/125 [==============================] - 69s 550ms/step - loss: 1.1065 - accuracy: 0.8148 - val_loss: 1.7744 - val_accuracy: 0.7522
# Epoch 11/20
# 125/125 [==============================] - 74s 595ms/step - loss: 1.0368 - accuracy: 0.8217 - val_loss: 1.7519 - val_accuracy: 0.7536
# Epoch 12/20
# 125/125 [==============================] - 68s 544ms/step - loss: 0.9728 - accuracy: 0.8275 - val_loss: 1.7333 - val_accuracy: 0.7568
# Epoch 13/20
# 125/125 [==============================] - 64s 516ms/step - loss: 0.9219 - accuracy: 0.8318 - val_loss: 1.7190 - val_accuracy: 0.7599
# Epoch 14/20
# 125/125 [==============================] - 64s 516ms/step - loss: 0.8643 - accuracy: 0.8383 - val_loss: 1.7101 - val_accuracy: 0.7625
# Epoch 15/20
# 125/125 [==============================] - 68s 542ms/step - loss: 0.8106 - accuracy: 0.8439 - val_loss: 1.6959 - val_accuracy: 0.7644
# Epoch 16/20
# 125/125 [==============================] - 82s 658ms/step - loss: 0.7711 - accuracy: 0.8485 - val_loss: 1.6971 - val_accuracy: 0.7648
# Epoch 17/20
# 125/125 [==============================] - 72s 573ms/step - loss: 0.7249 - accuracy: 0.8540 - val_loss: 1.6811 - val_accuracy: 0.7675
# Epoch 18/20
# 125/125 [==============================] - 83s 663ms/step - loss: 0.6899 - accuracy: 0.8583 - val_loss: 1.6848 - val_accuracy: 0.7681
# Epoch 19/20
# 125/125 [==============================] - 81s 646ms/step - loss: 0.6552 - accuracy: 0.8623 - val_loss: 1.6828 - val_accuracy: 0.7701
# Epoch 20/20
# 125/125 [==============================] - 71s 572ms/step - loss: 0.6180 - accuracy: 0.8668 - val_loss: 1.6842 - val_accuracy: 0.7701

# %%
from keras.layers import GRU

# %%
encoder_inputs = Input(shape=(max_input_len,))
encoder = GRU(LSTM_NODES, return_state=True)
encoder_outputs, state_h = encoder(encoder_inputs)

decoder_inputs = Input(shape=(max_out_len,))
decoder_gru = GRU(latent_dim, return_sequences=True)
decoder_outputs = decoder_gru(decoder_inputs, initial_state=state_h)
dropout = Dropout(rate=0.3)
decoder_outputs = dropout(decoder_outputs)
decoder_dense = Dense(num_words_output, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-2e07eaf2e284> in <module>
#       1 encoder_inputs = Input(shape=(max_input_len,))
#       2 encoder = GRU(LSTM_NODES, return_state=True)
# ----> 3 encoder_outputs, state_h = encoder(encoder_inputs)
#       4
#       5 decoder_inputs = Input(shape=(max_out_len,))
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     658
#     659     if initial_state is None and constants is None:
# --> 660       return super(RNN, self).__call__(inputs, **kwargs)
#     661
#     662     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     944     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     945       return self._functional_construction_call(inputs, args, kwargs,
# --> 946                                                 input_list)
#     947
#     948     # Maintains info about the `Layer.call` stack.
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1082       # Check input assumptions set after layer building, e.g. input shape.
#    1083       outputs = self._keras_tensor_symbolic_call(
# -> 1084           inputs, input_masks, args, kwargs)
#    1085
#    1086       if outputs is None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     814       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     815     else:
# --> 816       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     817
#     818   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     852           # overridden).
#     853           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 854           self._maybe_build(inputs)
#     855           inputs = self._maybe_cast_inputs(inputs)
#     856           outputs = call_fn(inputs, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2574     if not self.built:
#    2575       input_spec.assert_input_compatibility(
# -> 2576           self.input_spec, inputs, self.name)
#    2577       input_list = tf.nest.flatten(inputs)
#    2578       if input_list and self._dtype_policy.compute_dtype is None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     214                          'expected ndim=' + str(spec.ndim) + ', found ndim=' +
#     215                          str(ndim) + '. Full shape received: ' +
# --> 216                          str(tuple(shape)))
#     217     if spec.max_ndim is not None:
#     218       ndim = x.shape.rank
#
# ValueError: Input 0 of layer gru_1 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 5)

# %%
model4 = Model([encoder_inputs_placeholder,decoder_inputs_placeholder], decoder_outputs)
model4.compile(
    optimizer='Adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
r = model4.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets_one_hot,
    batch_size=BATCH_SIZE,
    epochs=50,
    validation_split=0.3,
)
